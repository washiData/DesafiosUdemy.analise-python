# %%
import pandas as pd

# %%
import numpy as np

# %%
covid_br = pd.read_csv("C:/covidbr.csv", sep =';') # carregando os dados csv

# %%
covid_br.head()#visualizando as primeiras linhas
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2022-01-01         52       210147125.0      22291507.0        3986
# 1  2022-01-02          1       210147125.0      22293228.0        1721
# 2  2022-01-03          1       210147125.0      22305078.0       11850
# 3  2022-01-04          1       210147125.0      22323837.0       18759
# 4  2022-01-05          1       210147125.0      22351104.0       27267
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %%
covid_br# visualizando o total de linhas e colunas
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1017034  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017035  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017036  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017037  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1017038  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
covid_br[covid_br.estado.isna()]
# Out:
#      regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4    Brasil    NaN       NaN     76     NaN             NaN             NaN
# ..      ...    ...       ...    ...     ...             ...             ...
# 176  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 177  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 178  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 179  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 180  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
# ...

# %%
missing_values_count = covid_br.isnull().sum()#obtendo dados ausentes por colunas

# %%
missing_values_count[0:10]# obtendo dados ausentes das 10 primeiras colunas
# Out:
# regiao                 0
# estado               181
# municipio           8869
# coduf                  0
# codmun              5068
# codRegiaoSaude      8869
# nomeRegiaoSaude     8869
# data                   0
# semanaEpi              0
# populacaoTCU2019    3801
# dtype: int64

# %%
total_cells = np.product(covid_br.shape)
total_missing = missing_values_count.sum()

# %%
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 12.02014174596694

# %%
covid_br.dropna()# eliminando dados ausentes
# Out:
# Empty DataFrame
# Columns: [regiao, estado, municipio, coduf, codmun, codRegiaoSaude, nomeRegiaoSaude, data, semanaEpi, populacaoTCU2019, casosAcumulado, casosNovos, obitosAcumulado, obitosNovos, Recuperadosnovos, AcompanhamentosNovos, interior/metropolitana]
# Index: []

# %%
columns_with_na_dropped = covid_br.dropna(axis=1)
columns_with_na_dropped.head()#remova todas as colunas com pelo menos um valor ausente
# Out:
#    regiao  coduf        data  semanaEpi  casosAcumulado  casosNovos  \
# 0  Brasil     76  2022-01-01         52      22291507.0        3986
# 1  Brasil     76  2022-01-02          1      22293228.0        1721
# 2  Brasil     76  2022-01-03          1      22305078.0       11850
# 3  Brasil     76  2022-01-04          1      22323837.0       18759
# 4  Brasil     76  2022-01-05          1      22351104.0       27267
#
#    obitosAcumulado  obitosNovos
# 0           619105           49
# 1           619133           28
# 2           619209           76
# 3           619384          175
# 4           619513          129

# %%
print("Columns in original dataset: %d \n" % covid_br.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])# quantos dados perdemos
# Out:
# Columns in original dataset: 17
#
# Columns with na's dropped: 8

# %%
subset_covid_br = covid_br.loc[:, 'regiao':'interior/metropolitana'].head()
subset_covid_br
# Out:
#    regiao estado municipio  coduf  codmun  codRegSaude nomeReg/Saude  \
# 0  Brasil    NaN       NaN     76     NaN          NaN           NaN
# 1  Brasil    NaN       NaN     76     NaN          NaN           NaN
# 2  Brasil    NaN       NaN     76     NaN          NaN           NaN
# 3  Brasil    NaN       NaN     76     NaN          NaN           NaN
# 4  Brasil    NaN       NaN     76     NaN          NaN           NaN
#
#          data  semanaEpi  pop/TCU2019  casosAcumulado  casosNovos  \
# 0  2022-01-01         52  210147125.0      22291507.0        3986
# 1  2022-01-02          1  210147125.0      22293228.0        1721
# 2  2022-01-03          1  210147125.0      22305078.0       11850
# 3  2022-01-04          1  210147125.0      22323837.0       18759
# 4  2022-01-05          1  210147125.0      22351104.0       27267
#
#    obitosAcumulado  obitosNovos  Recup/novos  Acompanh/Novos  \
# 0           619105           49   21581668.0         90734.0
# ...

# %%
subset_covid_br.fillna(0)# substituindo Nans por 0
# Out:
#    regiao  estado  municipio  coduf  codmun  codRegSaude  nomeReg/Saude  \
# 0  Brasil       0          0     76     0.0          0.0              0
# 1  Brasil       0          0     76     0.0          0.0              0
# 2  Brasil       0          0     76     0.0          0.0              0
# 3  Brasil       0          0     76     0.0          0.0              0
# 4  Brasil       0          0     76     0.0          0.0              0
#
#          data  semanaEpi  pop/TCU2019  casosAcumulado  casosNovos  \
# 0  2022-01-01         52  210147125.0      22291507.0        3986
# 1  2022-01-02          1  210147125.0      22293228.0        1721
# 2  2022-01-03          1  210147125.0      22305078.0       11850
# 3  2022-01-04          1  210147125.0      22323837.0       18759
# 4  2022-01-05          1  210147125.0      22351104.0       27267
#
#    obitosAcumulado  obitosNovos  Recup/novos  Acompanh/Novos  \
# 0           619105           49   21581668.0         90734.0
# ...

# %%
subset_covid_br.fillna(method='bfill', axis=0).fillna(0)
# Out:
#    regiao  estado  municipio  coduf  codmun  codRegSaude  nomeReg/Saude  \
# 0  Brasil     0.0        0.0     76     0.0          0.0            0.0
# 1  Brasil     0.0        0.0     76     0.0          0.0            0.0
# 2  Brasil     0.0        0.0     76     0.0          0.0            0.0
# 3  Brasil     0.0        0.0     76     0.0          0.0            0.0
# 4  Brasil     0.0        0.0     76     0.0          0.0            0.0
#
#          data  semanaEpi  pop/TCU2019  casosAcumulado  casosNovos  \
# 0  2022-01-01         52  210147125.0      22291507.0        3986
# 1  2022-01-02          1  210147125.0      22293228.0        1721
# 2  2022-01-03          1  210147125.0      22305078.0       11850
# 3  2022-01-04          1  210147125.0      22323837.0       18759
# 4  2022-01-05          1  210147125.0      22351104.0       27267
#
#    obitosAcumulado  obitosNovos  Recup/novos  Acompanh/Novos  \
# 0           619105           49   21581668.0         90734.0
# ...

# %%
covid_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017039 entries, 0 to 1017038
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   regiao                  1017039 non-null  object
#  1   estado                  1016858 non-null  object
#  2   municipio               1008170 non-null  object
#  3   coduf                   1017039 non-null  int64
#  4   codmun                  1011971 non-null  float64
#  5   codRegSaude             1008170 non-null  float64
#  6   nomeReg/Saude           1008170 non-null  object
#  7   data                    1017039 non-null  object
#  8   semanaEpi               1017039 non-null  int64
#  9   pop/TCU2019             1013238 non-null  float64
#  10  casosAcumulado          1017039 non-null  float64
#  11  casosNovos              1017039 non-null  int64
#  12  obitosAcumulado         1017039 non-null  int64
# ...

# %%
covid_br[covid_br.estado.isna()].casosAcumulado.plot()
# Out:
# <AxesSubplot:>

# %%
covid_br.describe()# visualizando dados estasticos
# Out:
#               coduf        codmun   codRegSaude     semanaEpi   pop/TCU2019  \
# count  1.017039e+06  1.011971e+06  1.008170e+06  1.017039e+06  1.013238e+06
# mean   3.236038e+01  3.252580e+05  3.240312e+04  1.357459e+01  1.126190e+05
# std    9.873301e+00  9.853507e+04  9.836346e+03  7.938386e+00  2.935316e+06
# min    1.100000e+01  1.100000e+05  1.100100e+04  1.000000e+00  7.810000e+02
# 25%    2.500000e+01  2.512000e+05  2.501000e+04  7.000000e+00  5.474000e+03
# 50%    3.100000e+01  3.146100e+05  3.105900e+04  1.300000e+01  1.168900e+04
# 75%    4.100000e+01  4.119150e+05  4.101500e+04  2.000000e+01  2.576200e+04
# max    7.600000e+01  5.300100e+05  5.300100e+04  5.200000e+01  2.101471e+08
#
#        casosAcumulado    casosNovos  obitosAcumulado   obitosNovos  \
# count    1.017039e+06  1.017039e+06     1.017039e+06  1.017039e+06
# mean     1.538541e+04  2.970534e+01     3.481823e+02  1.544484e-01
# std      4.013135e+05  1.135551e+03     9.178285e+03  6.442226e+00
# ...
